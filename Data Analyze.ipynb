# %% [markdown]
# <center>
# <img src="https://img.gazeta.ru/files3/179/14096179/Depositphotos_303868220_L-pic_32ratio_900x600-900x600-31493.jpg" width="700">
#
# # Групповой проект
# </center>
#
# Цель - создание модели оценки справедливой стоимости квартир в Екатеринбурге.

# %% [markdown]
# ## Шаг 3: предварительныя обработка

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('output.xlsx')
df.head()
# Out:
#             author                                      link          city  \
# 0  TEN девелопмент  https://ekb.cian.ru/sale/flat/282900962/  Екатеринбург
# 1  TEN девелопмент  https://ekb.cian.ru/sale/flat/255177069/  Екатеринбург
# 2           Эталон  https://ekb.cian.ru/sale/flat/283487334/  Екатеринбург
# 3  TEN девелопмент  https://ekb.cian.ru/sale/flat/284939234/  Екатеринбург
# 4           Эталон  https://ekb.cian.ru/sale/flat/279479083/  Екатеринбург
#
#   deal_type accommodation_type  floor  floors_count  rooms_count  \
# 0      sale               flat      1            31            1
# 1      sale               flat     25            31            1
# 2      sale               flat     14            25            1
# 3      sale               flat      2            19            1
# 4      sale               flat     14            16            1
#
#    total_meters    price  year_of_construction  living_meters  kitchen_meters  \
# 0         30.60  3673800                  2023           14.0             7.0
# 1         35.80  5284000                  2023           12.0            12.0
# 2         37.99  4835128                  2022           16.0            11.0
# 3         32.50  4106000                  2025           10.0            10.0
# 4         42.00  4158074                  2022            8.0            21.0
#
#          phone           district             street           underground  \
# 0  73432261182         Чкаловский        Светлый мкр          Ботаническая
# 1  73432261244          Ленинский  Академика Бардина            Чкаловская
# 2  73432267743        Октябрьский     Южный жилрайон          Ботаническая
# 3  73432261243  Орджоникидзевский           Учителей      Машиностроителей
# 4  73432260512                NaN                NaN  Проспект Космонавтов
#
#     residential_complex
# 0               Светлый
# 1        Дом на Бардина
# 2       Суомен Ранта ЖК
# 3  Основинские кварталы
# 4                   NaN

# %% [markdown]
# Посмотрим на наши данные в целом: какой размер датасета, какие есть столбцы и какие типы данных в них содержатся, сколько пропусков.

# %%
print(df.shape)
pd.concat([df.dtypes, df.isna().sum()], axis=1, keys=['dtypes', 'missing'])
# Out:
# (4197, 18)
#                        dtypes  missing
# author                 object      266
# link                   object        0
# city                   object        0
# deal_type              object        0
# accommodation_type     object        0
# floor                   int64        0
# floors_count            int64        0
# rooms_count             int64        0
# total_meters          float64        0
# price                   int64        0
# year_of_construction    int64        0
# living_meters         float64        0
# kitchen_meters        float64        0
# phone                   int64        0
# district               object      595
# street                 object     1623
# underground            object     1074
# residential_complex    object     1319

# %% [markdown]
# У нас есть следующие колонки:
#
# - Автор объявления
#
# - Ссылка на объявление
#
# - Город
#
# - Тип сделки
#
# - Тип недвижимости
#
# - Этаж
#
# - Общее количество этажей
#
# - Количество комнат
#
# - Общая площадь
#
# - Стоимость
#
# - Год постройки
#
# - Жилая площадь
#
# - Площадь кухни
#
# - Номер телевона автора объявления
#
# - Район
#
# - Улица
#
# - Ближайшее метро
#
# - Название жилого комплекса
#
# В ходе работы нам вряд ли понадобится следующая информация: ссылка на объявление, город (мы работаем только с недвижимостью Екатеринбурга), тип сделки (у нас везде продажа), тип недвижимости (мы работаем только с квартирами), количество комнат (мы рассматриваем только студии и однушки, то есть везде будет одна), номер телефона, улица, название жилого комплекса. Удалим эти колонки.

# %%
df = df.drop(['link', 'city', 'deal_type', 'accommodation_type', 'rooms_count', 
              'phone', 'street', 'residential_complex'], axis=1)
df.head()
# Out:
#             author  floor  floors_count  total_meters    price  \
# 0  TEN девелопмент      1            31         30.60  3673800
# 1  TEN девелопмент     25            31         35.80  5284000
# 2           Эталон     14            25         37.99  4835128
# 3  TEN девелопмент      2            19         32.50  4106000
# 4           Эталон     14            16         42.00  4158074
#
#    year_of_construction  living_meters  kitchen_meters           district  \
# 0                  2023           14.0             7.0         Чкаловский
# 1                  2023           12.0            12.0          Ленинский
# 2                  2022           16.0            11.0        Октябрьский
# 3                  2025           10.0            10.0  Орджоникидзевский
# 4                  2022            8.0            21.0                NaN
#
#             underground
# 0          Ботаническая
# 1            Чкаловская
# 2          Ботаническая
# 3      Машиностроителей
# 4  Проспект Космонавтов

# %% [markdown]
# Теперь поработаем с колонками, где у нас есть пропуски, попробуем заполнить их.
#
# Начнем с автора объявления.

# %%
print(df['author'].value_counts().to_string(max_rows=None))
# Out:
# TEN девелопмент                                  746
# Эталон                                           302
# Брусника                                         258
# Диал                                             158
# Новосёл                                          157
# АЗБУКА НЕДВИЖИМОСТИ                              154
# ID 70812476                                      150
# Этажи Нижний Тагил                               129
# ПИК                                              109
# Прогресс                                         101
# ID 70812431                                       97
# ID 96546420                                       97
# Академический                                     79
# Fortis Development                                72
# Стройтэк                                          66
# Этажи Екатеринбург                                64
# ЛСР. Недвижимость                                 59
# Корпорация Маяк                                   53
# Самолет Плюс Екатеринбург                         53
# ID 49047485                                       51
# Корпорация Маяк - отдел недвижимости              51
# ACONS GROUP                                       50
# Девелопмент-юг                                    50
# ДОБРОДЕЛ                                          35
# Ривьера-Инвест-Екб                                32
# Содружество                                       31
# АТОМ                                              30
# Астра                                             27
# Столица                                           24
# Этажи Талица                                      23
# Самолет Плюс Екатеринбург-Верхняя Пышма           21
# Синара–Девелопмент                                18
# Ярмарка                                           18
# ЭкоЛайн                                           16
# Форум-групп                                       14
# Ориентир. Недвижимость                            14
# ДОМОС                                             14
# Этажи Алапаевск                                   13
# НКС-Девелопмент                                   12
# ID 49343725                                       12
# Макромир Екатеринбург                             12
# Екатеринбургская служба Недвижимости и оценки     12
# ДомИнвест                                         11
# МЕТРЫ                                             10
# Новый ориентир                                    10
# УГМК-Застройщик                                   10
# Миэль Офис в Екатеринбурге                         9
# Дом мечты                                          8
# АРСЕНАЛ                                            8
# Гринвич                                            8
# ЛИНК                                               7
# Регион-Маркет                                      7
# ГРАНАТ                                             7
# МФЦ Недвижимость                                   7
# Русский Дом МК                                     7
# Северная казна                                     7
# СКМ Девелопмент                                    7
# Арсенал и К                                        7
# НОВОГРАД                                           6
# Atlas Development                                  6
# Астон                                              6
# Центр Ипотеки и Недвижимости Екатеринбург          6
# Правобережный                                      6
# ЮРИЭЛТ                                             6
# БЕЛКА                                              6
# Новая Квартира                                     6
# УРАЛКОМПЛЕКТ                                       6
# ГеоИнвест                                          6
# Удачное                                            5
# ТПФ ЮТ                                             5
# СВИТ ХОУМ                                          5
# Северная казна Бюро                                5
# Клевер-Групп                                       5
# Новосел                                            5
# PR FLAT                                            4
# ДИККИТ                                             4
# Формат                                             4
# Без Границ                                         4
# Солнечный дом                                      4
# DREAM ROOMS                                        4
# Виктория                                           4
# Орион                                              4
# Недвижимость 96                                    4
# Арбат                                              4
# ПРАКТИКА                                           4
# Городок Арамиль                                    4
# Первостроитель                                     4
# Премьерстрой                                       3
# 4 ВЕТРА                                            3
# TIME-HOME                                          3
# H2O                                                3
# Формула Строительства                              3
# Риэлтерский центр Недвижимость                     3
# Горжилстрой                                        3
# Уральская Губерния                                 3
# РАЙТ ФИНАНС                                        3
# Союз                                               3
# Принцип недвижимость                               3
# Исток                                              3
# Новосёл Сысерть                                    3
# РЕПУТАЦИЯ                                          3
# ID 70812617                                        3
# Юность                                             3
# Федерация                                          2
# Виталий Алексеев                                   2
# Новостройки Екатеринбурга                          2
# ID 15271707                                        2
# Твой Квадрат                                       2
# Уральский Дом Недвижимости                         2
# ОбменКвартир                                       2
# Новосёл офис Амундсена                             2
# Адрес                                              2
# Актив                                              2
# Юнихоум                                            2
# 5 Авеню                                            2
# Кодекс                                             2
# Жизнь                                              2
# Екатерина Клементьева                              2
# ID 23570334                                        2
# Харланов и партнеры                                2
# Сбербанк                                           2
# Академическое                                      2
# РК Уральский дом недвижимости                      2
# Рио-Люкс                                           2
# Кристалл-Инвест                                    2
# ID 57165878                                        2
# Клевер                                             2
# Евгений Щербаков                                   2
# Квартет-бюро                                       2
# Инна Ермолина                                      2
# Агентство Ипотечное ЕКБ                            2
# Фирма Сысерть Недвижимость                         1
# Недвижимость24.ру                                  1
# Лидия Горбунова                                    1
# Гармония Вашего Дома                               1
# Синергия                                           1
# Домкомм                                            1
# ID 48598945                                        1
# ID 6359854                                         1
# Самолет Плюс                                       1
# ID 6572830                                         1
# Корифей                                            1
# АльфаХоум                                          1
# ID 100854234                                       1
# АН-2                                               1
# Центр недвижимости Вознесенский                    1
# ID 97007274                                        1
# ID 72984958                                        1
# Елена Токманцева                                   1
# МАЯК НЕДВИЖИМОСТЬ                                  1
# Инна Шпигель                                       1
# А.ЛИРА                                             1
# ID 97223011                                        1
# ГОРОД                                              1
# Анастасия Кропачева                                1
# ID 47864644                                        1
# Юля Бочегова                                       1
# ID 19718917                                        1
# ID 84456897                                        1
# ID 72116565                                        1
# КУРМАЧЁВ                                           1
# Рафаил Микаилов                                    1
# ID 81210459                                        1
# ID 88943253                                        1
# Сысертская усадьба                                 1
# ID 19423901                                        1
# ID 100247475                                       1
# ID 93219370                                        1
# Азбука жилья                                       1
# ID 102064172                                       1
# Надежда Хлебникова                                 1
# Альянс-Строй                                       1
# Бюро недвижимости 1                                1
# ID 80984598                                        1
# Дмитрий Королев                                    1
# ID 102022729                                       1
# ID 46900857                                        1
# Дмитрий Кадочников                                 1
# ID 15932547                                        1
# ID 70812738                                        1
# Регион 96                                          1
# ID 95202357                                        1
# Виталия                                            1
# SRG                                                1
# Северная казна Тбилисский                          1
# Виктор Максимовский                                1
# Светлана Бутылина                                  1
# Ника                                               1
# КомиссиON ВТБ                                      1
# Совкомбанк                                         1
# ID 96130372                                        1
# Эльдар Мустафаев                                   1
# ID 46829274                                        1
# ID 70812452                                        1
# Дмитрий Антипин                                    1
# Лофт недвижимость                                  1
# Л и ПАРТНЕРЫ                                       1
# ID 30772358                                        1
# ID 57412871                                        1
# РИЭЛТ ХАУС                                         1
# ID 70812435                                        1
# ID 77670452                                        1

# %% [markdown]
# Нам скорее интересен не сам автор объявления, а является ли он частным собственником или работает через посредника-агентство недвижимости / является застройщиком. Создадим новую колонку *owner* и заполним её False, если от автора есть более одного объявления, и True, в остальных случаях (пропуски тоже). После удалим колонку *author*.

# %%
df['owner'] = df['author'].duplicated(keep=False).apply(lambda x: not x)
df.loc[df['author'].isna(), 'owner'] = True
df = df.drop(['author'], axis=1)
df.head()
# Out:
#    floor  floors_count  total_meters    price  year_of_construction  \
# 0      1            31         30.60  3673800                  2023
# 1     25            31         35.80  5284000                  2023
# 2     14            25         37.99  4835128                  2022
# 3      2            19         32.50  4106000                  2025
# 4     14            16         42.00  4158074                  2022
#
#    living_meters  kitchen_meters           district           underground  \
# 0           14.0             7.0         Чкаловский          Ботаническая
# 1           12.0            12.0          Ленинский            Чкаловская
# 2           16.0            11.0        Октябрьский          Ботаническая
# 3           10.0            10.0  Орджоникидзевский      Машиностроителей
# 4            8.0            21.0                NaN  Проспект Космонавтов
#
#    owner
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %% [markdown]
# Теперь рассмотрим колонку *district*.

# %%
df['district'].value_counts()
# Out:
# Ленинский                                                                                                                583
# Верх-Исетский                                                                                                            540
# Чкаловский                                                                                                               456
# Кировский                                                                                                                402
# Октябрьский                                                                                                              382
# Орджоникидзевский                                                                                                        365
# Центр                                                                                                                    278
# Железнодорожный                                                                                                          276
# Автовокзал                                                                                                               225
# Тагилстроевский                                                                                                           55
# Дзержинский                                                                                                               24
# Синарский                                                                                                                  3
# ЖК «Кварталы Форум Групп ( Солнечный)»дом сданБотаническая10 минут на транспортеСвердловская область                       3
# ЖК «Кварталы Форум Групп ( Солнечный)»Свердловская область                                                                 3
# ЖК «Кварталы Форум Групп ( Солнечный)»Ботаническая10 минут на транспортеСвердловская область                               3
# ЖК «Квартал Брусника ( Солнечный)»Ботаническая11 минут на транспортеСвердловская область                                   1
# Красногорский                                                                                                              1
# ЖК «Квартал Астра ( Солнечный)»Ботаническая10 минут на транспортеСвердловская область                                      1
# 2 кв. м. в Посёлке городского типа Белоярский.\n\nРАЙОН:\nБелоярский .\n\nДВОР:\nОборудован детской игровой площадкой      1
# Name: district, dtype: int64

# %% [markdown]
# Нам нужно сначала привести к нормальному виду район Солнечный. Наблюдения с районами Красногорский, Сысертский, Белоярский можно удалить, т.к. там мало наблюдений.

# %%
df['district'] = df['district'].apply(lambda x: 'Солнечный' if isinstance(x, str) and 'Солнечный' in x else x)
df.drop(df.loc[df['district'] == 'Красногорский'].index, inplace=True)
df.drop(df.loc[df['district'] == 'Синарский'].index, inplace=True)
df.drop(df.loc[df['district'] == 'уютная квартира в Сысертском е'].index, inplace=True)
df.drop(df.loc[df['district'] == '2 кв. м. в Посёлке городского типа Белоярский.\n\nРАЙОН:\nБелоярский .\n\nДВОР:\nОборудован детской игровой площадкой'].index, inplace=True)

df['district'].value_counts()
# Out:
# Ленинский            583
# Верх-Исетский        540
# Чкаловский           456
# Кировский            402
# Октябрьский          382
# Орджоникидзевский    365
# Центр                278
# Железнодорожный      276
# Автовокзал           225
# Тагилстроевский       55
# Дзержинский           24
# Солнечный             11
# Name: district, dtype: int64

# %% [markdown]
# Теперь займемся пропусками. Создадим подтаблицу только со строками, где в нашем столбце пропуск.

# %%
df_no_district = df.loc[df['district'].isna()]
print(df_no_district.shape)
df_no_district.isna().sum()
# Out:
# (595, 10)
# floor                     0
# floors_count              0
# total_meters              0
# price                     0
# year_of_construction      0
# living_meters             0
# kitchen_meters            0
# district                595
# underground             408
# owner                     0
# dtype: int64

# %% [markdown]
# Тут можно заметить, что даже если отсутствует район, у многих наблюдений есть информация о метро. Попробуем воспользоваться этой информацией. Сначала удалим все строки, где неизвестно ни метро, ни район.

# %%
df.dropna(subset=['district', 'underground'], how='all', inplace=True)
df.shape
# Out:
# (3784, 10)

# %% [markdown]
# Теперь, если мы знаем, какое метро у квартиры, мы можем посмотреть, какой район чаще всего указывают для этого метро и заполнить пропуски по недостающим районам. В обратную сторону мы так не можем сделать, так как пропуск в столбце *underground* может просто указывать на то, что рядом метро нет.

# %%
# создаем словарь для хранения самых популярных значений district для каждого значения underground
underground_districts = {}

# проходим по каждому уникальному значению в столбце 'underground'
for underground in df['underground'].unique():
    # получаем все наблюдения с заданным значением в столбце 'underground'
    mask = df['underground'] == underground
    # получаем список значений 'district' для заданного значения 'underground'
    districts = df.loc[mask, 'district']
    # находим самое популярное значение 'district' для заданного значения 'underground'
    if len(districts) > 0:
        most_common_district = districts.mode().values[0]
        # добавляем значение 'most_common_district' в словарь для заданного значения 'underground'
        underground_districts[underground] = most_common_district

# заменяем пропущенные значения в столбце 'district'
for i, row in df.iterrows():
    # проверяем, является ли значение в столбце 'district' пропущенным
    if pd.isna(row['district']):
        # получаем значение в столбце 'underground' для данной строки
        underground = row['underground']
        # находим самое популярное значение 'district' для данного значения 'underground'
        if underground in underground_districts:
            most_common_district = underground_districts[underground]
            # заменяем пропущенное значение в столбце 'district' на самое популярное значение 'district'
            df.at[i, 'district'] = most_common_district

# %% [markdown]
# Как уже было сказано, пропуски в столбце с метро не являются по сути своей пропусками, это лишь значит, что поблизости нет метро. Так и запишем в датафрейме.

# %%
df['underground'] = df['underground'].fillna('Нет метро')

# %%
df.isna().sum()
# Out:
# floor                   0
# floors_count            0
# total_meters            0
# price                   0
# year_of_construction    0
# living_meters           0
# kitchen_meters          0
# district                0
# underground             0
# owner                   0
# dtype: int64

# %% [markdown]
# Посмотрим еще раз внимательно на датасет

# %%
df.describe()
# Out:
#              floor  floors_count  total_meters         price  \
# count  3784.000000   3784.000000   3784.000000  3.784000e+03
# mean      8.145877     18.443446     44.032479  4.956469e+06
# std       7.332903      8.400872     34.457797  2.187324e+06
# min       1.000000      1.000000     10.700000  5.700000e+05
# 25%       2.000000     10.000000     32.600000  3.870000e+06
# 50%       6.000000     19.000000     36.400000  4.568814e+06
# 75%      11.000000     25.000000     42.400000  5.600000e+06
# max      35.000000     37.000000    333.400000  3.870000e+07
#
#        year_of_construction  living_meters  kitchen_meters
# count           3784.000000    3784.000000     3784.000000
# mean            1987.360994       9.894080        8.982796
# std              235.474244       8.365313        7.305833
# min               -1.000000      -1.000000       -1.000000
# 25%             2022.000000      -1.000000       -1.000000
# 50%             2023.000000      11.000000       10.000000
# 75%             2024.000000      15.100000       15.000000
# max             2026.000000     233.000000       55.000000

# %% [markdown]
# В столбцах *year_of_construction, living_meters, kitchen_meters* есть значения равные -1. В документация библиотеки написано, что это тоже пропуски. Так как здесь мы работаем уже с цифрами, то логичнее всего заполнить пропуски медианой. Но перед этим надо удалить минус единицы из её рассчета.

# %%
# заменяем все значения равные -1 на NaN
df = df.replace(-1, np.nan)

# вычисляем медианы столбцов, исключая NaN значения
medians = df.median(skipna=True)

# заменяем все NaN значения в каждом столбце на соответствующую медиану
for col in ['year_of_construction', 'living_meters', 'kitchen_meters']:
    df[col] = df[col].fillna(medians[col])

# %% [markdown]
# Теперь удалим выбросы по колонкам общей, жилой, кухонной площади, а также цены. Будем использвать Z-score со значением 3, то есть данные должны отклоняться от среднего не более чем на 3 стандартных отклонения.

# %%
def remove_outliers_zscore(df, columns, threshold):
    # создаем копию датафрейма
    df_clean = df.copy()

    # итерируемся по столбцам
    for col in columns:
        # вычисляем Z-оценку для каждого значения в столбце
        z_scores = np.abs(stats.zscore(df_clean[col]))

        # создаем маску, чтобы выбрать только значения, которые не являются выбросами
        mask = z_scores < threshold

        # заменяем значения в столбце на NaN, если они являются выбросами
        df_clean.loc[~mask, col] = np.nan

    # удаляем строки с пропущенными значениями
    df_clean.dropna(inplace=True)

    return df_clean

# %%
# удаляем выбросы из столбцов с порогом 3
df = remove_outliers_zscore(df, ['total_meters', 'living_meters', 'kitchen_meters', 'price'], 3)
df.shape
# Out:
# (3536, 10)

# %%
df.describe()
# Out:
#              floor  floors_count  total_meters         price  \
# count  3536.000000   3536.000000   3536.000000  3.536000e+03
# mean      8.400735     18.806844     36.454010  4.718321e+06
# std       7.450111      8.475659      6.646331  1.599847e+06
# min       1.000000      1.000000     10.700000  5.700000e+05
# 25%       2.000000     11.000000     32.500000  3.750000e+06
# 50%       6.000000     19.000000     35.900000  4.488416e+06
# 75%      12.000000     25.000000     41.800000  5.437678e+06
# max      35.000000     37.000000     87.500000  1.009900e+07
#
#        year_of_construction  living_meters  kitchen_meters
# count           3536.000000    3536.000000     3536.000000
# mean            2014.593043      13.913914       12.259474
# std               19.131876       3.251831        4.090091
# min             1917.000000       3.000000        3.000000
# 25%             2022.000000      12.000000       10.000000
# 50%             2023.000000      14.000000       13.000000
# 75%             2024.000000      15.100000       14.000000
# max             2026.000000      29.000000       25.000000

# %%
df['year_of_construction'] = df['year_of_construction'].astype(int)

# %% [markdown]
# Кажется, стало лучше.
